# %% [raw]
# # Lab 1 - Data Structures and Sorting
#
#
# ### Submission instructions
# #### Turn in the lab via Canvas Assignments today (Thus, ) by 11:59pm today.
# After completing this lab, you will turn in two files via Canvas ->  Assignments -> Lab 1:
# Your Notebook, named si330-hw1-YOUR_UNIQUE_NAME.ipynb and
# the HTML file, named si330-hw1-YOUR_UNIQUE_NAME.html
#
# ### Name:  Libby Murray
# ### Uniqname:90594386
# ### People you worked with: [if you didn't work with anyone else write "I worked by myself" here]. Francisco Gallardo
#
# ## Objectives
# After completing this homework assignment, you should know how to
# * use compound data structures
# * perform simple and complex sorting
# * use lambda functions
#
# In addition, this assignment will provide an opportunity to work with a large (100,000 row) data set.
#
# ## Background
#
# Massive Open Online Courses (MOOCs) are a popular way for people to learn new skills.  The University of Michigan
# offers many different MOOCs, which are produced by faculty members and supported by the Office of Academic
# Innovation.
#
# MOOCs tend to be used by hundreds to hundreds of thousands of users.  These users leave "digital exhaust" when
# they work through the MOOC in the form of web server log entries.  We have obtained a small sample of these data
# files from Prof. Chris Brooks, who is a colleague here at UMSI.  The data files are de-identified: anything
# that could identify a person, such as their UMID or their IP address are "hashed" (encrypted).  Each line in the
# data file represents a "page view" by a user.  The schema for each line is:
#
# ```umich_user_id, hashed_session_cookie_id, server_timestamp, hashed_ip, user_agent, url, initial_referrer_url, rowser_language, course_id, country_cd, region_cd, timezone, os, browser, key, value```
#
# **For this lab we will only concern ourselves with ```UMICH_USER_ID```, which identifies each user.**
#
# We will use the files **mooc_small.csv** and **countrycodes.tsv** for this lab.
#
# In the lab, we will go through the motions of some manipulation of the MOOC log data. These concepts would be tested in your homework assignment, where you will use these manipulations to answer some real world questions.

# %%
import csv
from collections import defaultdict

# %% [markdown]
# ### Importing the data
#
# The first step is to load the data. All the data about mooc usage and users are in the file mooc_small.csv. We also need the data from countrycodes.tsv to interpret the names of the country which are represented as country codes in ```mooc_small.csv```
#
# We want to know for a given two digit ```country_cd``` in ```mooc_small.csv```, the complete name of the country. Hence, we will import the country codes into a dictionary.

# %% [markdown]
# <font color="red">**Q: Explain why a dictionary is the best data structure to store this?**</font>

# %% [markdown]
# Write your answer here...

# %% [markdown]
# <font color="red">In the following chunk, write your code to populate the dictionary.</font>

# %%
### This chunk of code reads from a tab separated value file and stores the data in a dictionary
country_names = {}

with open("countrycodes.tsv", "r") as csvfile:
    reader = csv.DictReader(csvfile, delimiter = "\t", quotechar = '"')
    for row in reader:
        country_names[row['ISO ALPHA-2 Code']] = row ['Country or Area Name']
        # Change this line to populate the data structure you created above with the data from the file
        #print (country_names.keys())
        #print ('------')
        
print(country_names)
# Out:
# {'AF': 'Afghanistan', 'AX': 'Aland Islands', 'AL': 'Albania', 'DZ': 'Algeria', 'AS': 'American Samoa', 'AD': 'Andorra', 'AO': 'Angola', 'AI': 'Anguilla', 'AQ': 'Antarctica', 'AG': 'Antigua and Barbuda', 'AR': 'Argentina', 'AM': 'Armenia', 'AW': 'Aruba', 'AU': 'Australia', 'AT': 'Austria', 'AZ': 'Azerbaijan', 'BS': 'Bahamas', 'BH': 'Bahrain', 'BD': 'Bangladesh', 'BB': 'Barbados', 'BY': 'Belarus', 'BE': 'Belgium', 'BZ': 'Belize', 'BJ': 'Benin', 'BM': 'Bermuda', 'BT': 'Bhutan', 'BO': 'Bolivia', 'BA': 'Bosnia and Herzegovina', 'BW': 'Botswana', 'BV': 'Bouvet Island', 'BR': 'Brazil', 'VG': 'British Virgin Islands', 'IO': 'British Indian Ocean Territory', 'BN': 'Brunei Darussalam', 'BG': 'Bulgaria', 'BF': 'Burkina Faso', 'BI': 'Burundi', 'KH': 'Cambodia', 'CM': 'Cameroon', 'CA': 'Canada', 'CV': 'Cape Verde', 'KY': 'Cayman Islands', 'CF': 'Central African Republic', 'TD': 'Chad', 'CL': 'Chile', 'CN': 'China', 'HK': 'Hong Kong, SAR China', 'MO': 'Macao, SAR China', 'CX': 'Christmas Island', 'CC': 'Cocos (Keeling) Islands', 'CO': 'Colombia', 'KM': 'Comoros', 'CG': 'Congo (Brazzaville)', 'CD': 'Congo, (Kinshasa)', 'CK': 'Cook Islands', 'CR': 'Costa Rica', 'CI': "Cote d'Ivoire", 'HR': 'Croatia', 'CU': 'Cuba', 'CY': 'Cyprus', 'CZ': 'Czech Republic', 'DK': 'Denmark', 'DJ': 'Djibouti', 'DM': 'Dominica', 'DO': 'Dominican Republic', 'EC': 'Ecuador', 'EG': 'Egypt', 'SV': 'El Salvador', 'GQ': 'Equatorial Guinea', 'ER': 'Eritrea', 'EE': 'Estonia', 'ET': 'Ethiopia', 'FK': 'Falkland Islands (Malvinas)', 'FO': 'Faroe Islands', 'FJ': 'Fiji', 'FI': 'Finland', 'FR': 'France', 'GF': 'French Guiana', 'PF': 'French Polynesia', 'TF': 'French Southern Territories', 'GA': 'Gabon', 'GM': 'Gambia', 'GE': 'Georgia', 'DE': 'Germany', 'GH': 'Ghana', 'GI': 'Gibraltar', 'GR': 'Greece', 'GL': 'Greenland', 'GD': 'Grenada', 'GP': 'Guadeloupe', 'GU': 'Guam', 'GT': 'Guatemala', 'GG': 'Guernsey', 'GN': 'Guinea', 'GW': 'Guinea-Bissau', 'GY': 'Guyana', 'HT': 'Haiti', 'HM': 'Heard and Mcdonald Islands', 'VA': 'Holy See (Vatican City State)', 'HN': 'Honduras', 'HU': 'Hungary', 'IS': 'Iceland', 'IN': 'India', 'ID': 'Indonesia', 'IR': 'Iran, Islamic Republic of', 'IQ': 'Iraq', 'IE': 'Ireland', 'IM': 'Isle of Man', 'IL': 'Israel', 'IT': 'Italy', 'JM': 'Jamaica', 'JP': 'Japan', 'JE': 'Jersey', 'JO': 'Jordan', 'KZ': 'Kazakhstan', 'KE': 'Kenya', 'KI': 'Kiribati', 'KP': 'Korea (North)', 'KR': 'Korea (South)', 'KW': 'Kuwait', 'KG': 'Kyrgyzstan', 'LA': 'Lao PDR', 'LV': 'Latvia', 'LB': 'Lebanon', 'LS': 'Lesotho', 'LR': 'Liberia', 'LY': 'Libya', 'LI': 'Liechtenstein', 'LT': 'Lithuania', 'LU': 'Luxembourg', 'MK': 'Macedonia, Republic of', 'MG': 'Madagascar', 'MW': 'Malawi', 'MY': 'Malaysia', 'MV': 'Maldives', 'ML': 'Mali', 'MT': 'Malta', 'MH': 'Marshall Islands', 'MQ': 'Martinique', 'MR': 'Mauritania', 'MU': 'Mauritius', 'YT': 'Mayotte', 'MX': 'Mexico', 'FM': 'Micronesia, Federated States of', 'MD': 'Moldova', 'MC': 'Monaco', 'MN': 'Mongolia', 'ME': 'Montenegro', 'MS': 'Montserrat', 'MA': 'Morocco', 'MZ': 'Mozambique', 'MM': 'Myanmar', 'NA': 'Namibia', 'NR': 'Nauru', 'NP': 'Nepal', 'NL': 'Netherlands', 'AN': 'Netherlands Antilles', 'NC': 'New Caledonia', 'NZ': 'New Zealand', 'NI': 'Nicaragua', 'NE': 'Niger', 'NG': 'Nigeria', 'NU': 'Niue', 'NF': 'Norfolk Island', 'MP': 'Northern Mariana Islands', 'NO': 'Norway', 'OM': 'Oman', 'PK': 'Pakistan', 'PW': 'Palau', 'PS': 'Palestinian Territory', 'PA': 'Panama', 'PG': 'Papua New Guinea', 'PY': 'Paraguay', 'PE': 'Peru', 'PH': 'Philippines', 'PN': 'Pitcairn', 'PL': 'Poland', 'PT': 'Portugal', 'PR': 'Puerto Rico', 'QA': 'Qatar', 'RE': 'Reunion', 'RO': 'Romania', 'RU': 'Russian Federation', 'RW': 'Rwanda', 'BL': 'Saint-Barthlemy', 'SH': 'Saint Helena', 'KN': 'Saint Kitts and Nevis', 'LC': 'Saint Lucia', 'MF': 'Saint-Martin (French part)', 'PM': 'Saint Pierre and Miquelon', 'VC': 'Saint Vincent and Grenadines', 'WS': 'Samoa', 'SM': 'San Marino', 'ST': 'Sao Tome and Principe', 'SA': 'Saudi Arabia', 'SN': 'Senegal', 'RS': 'Serbia', 'SC': 'Seychelles', ...

# %% [markdown]
# Next we will import the data from ```mooc_small.csv``` into a list.
# <font color="red">In the following chunk, write your code to populate the list.</font>

# %%
mooc_data_file_name = "mooc.csv" # Remember to change this later

mooc_data = [] # None # Change this to create an appropriate data structure

with open(mooc_data_file_name, "r") as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        mooc_data.append(row)
    print (mooc_data)
    #pass # Add two lines to populate the data structure you created above with the data from the file
# Out:
# [OrderedDict([('umich_user_id', '0ea5cc6ff0ca76782e6c0a81f070cae9cf0971d9'), ('hashed_session_cookie_id', '67aeaede0738f24452327c34871463f0df2ad14f'), ('server_timestamp', 'Thu Jan 01 03:00:00 EST 2015'), ('hashed_ip', '18408ad2c5c0688ea5c09af9f468780eac9f4db6'), ('user_agent', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:34.0) Gecko/20100101 Firefox/34.0'), ('url', 'https://www.coursera.org/learn/negotiation-skills/lecture/5hVbj/contract-performance-review-and-evaluation'), ('initial_referrer_url', 'https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=1&ved=0CB8QFjAA&url=https%3A%2F%2Fwww.coursera.org%2F&ei=nOaQVMDjNcGwogTy9YK4DA&usg=AFQjCNEAm-45Muq_nX5INW96szY5GEJGUg&sig2=jbFxMTxvkK2gQnbgTEs63Q&bvm=bv.82001339,d.cGU'), ('browser_language', 'fr,fr-fr;q=0.8,en-us;q=0.5,en;q=0.3'), ('course_id', 'v0l76HmGEeSi3yIACzSGcw'), ('country_cd', 'PF'), ('region_cd', 'V'), ('timezone', 'Pacific/Tahiti'), ('os', 'Mac OS X'), ('browser', 'Firefox'), ('key', 'pageview'), ('value', '{}')]), OrderedDict([('umich_user_id', '0ea5cc6ff0ca76782e6c0a81f070cae9cf0971d9'), ('hashed_session_cookie_id', '67aeaede0738f24452327c34871463f0df2ad14f'), ('server_timestamp', 'Thu Jan 01 03:00:02 EST 2015'), ('hashed_ip', '18408ad2c5c0688ea5c09af9f468780eac9f4db6'), ('user_agent', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:34.0) Gecko/20100101 Firefox/34.0'), ('url', 'https://www.coursera.org/learn/negotiation-skills/supplement/NnHUS/suggested-readings'), ('initial_referrer_url', 'https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=1&ved=0CB8QFjAA&url=https%3A%2F%2Fwww.coursera.org%2F&ei=nOaQVMDjNcGwogTy9YK4DA&usg=AFQjCNEAm-45Muq_nX5INW96szY5GEJGUg&sig2=jbFxMTxvkK2gQnbgTEs63Q&bvm=bv.82001339,d.cGU'), ('browser_language', 'fr,fr-fr;q=0.8,en-us;q=0.5,en;q=0.3'), ('course_id', 'v0l76HmGEeSi3yIACzSGcw'), ('country_cd', 'PF'), ('region_cd', 'V'), ('timezone', 'Pacific/Tahiti'), ('os', 'Mac OS X'), ('browser', 'Firefox'), ('key', 'pageview'), ('value', '{}')]), OrderedDict([('umich_user_id', '5450de1c9e1874d613a9649a39352a10313a3b8f'), ('hashed_session_cookie_id', 'd136ec74794fa1f8897f065b2377c891d18baa0b'), ('server_timestamp', 'Thu Jan 01 03:00:04 EST 2015'), ('hashed_ip', '70fc3eb2f8ee1362c902a16875aa95ee1d7e8311'), ('user_agent', 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/534.24 (KHTML, like Gecko) Chrome/11.0.696.34 Safari/534.24'), ('url', 'https://www.coursera.org/learn/negotiation-skills/lecture/el26b/a-dispute-resolution-or-deal-making-negotiation'), ('initial_referrer_url', ''), ('browser_language', 'it-IT, en-US'), ('course_id', 'v0l76HmGEeSi3yIACzSGcw'), ('country_cd', 'IT'), ('region_cd', 'GE'), ('timezone', 'Europe/Rome'), ('os', 'Linux'), ('browser', 'Chrome'), ('key', 'pageview'), ('value', '{}')]), OrderedDict([('umich_user_id', '0ea5cc6ff0ca76782e6c0a81f070cae9cf0971d9'), ('hashed_session_cookie_id', '67aeaede0738f24452327c34871463f0df2ad14f'), ('server_timestamp', 'Thu Jan 01 03:00:04 EST 2015'), ('hashed_ip', '18408ad2c5c0688ea5c09af9f468780eac9f4db6'), ('user_agent', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:34.0) Gecko/20100101 Firefox/34.0'), ('url', 'https://www.coursera.org/learn/negotiation-skills/lecture/5hVbj/contract-performance-review-and-evaluation'), ('initial_referrer_url', 'https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=1&ved=0CB8QFjAA&url=https%3A%2F%2Fwww.coursera.org%2F&ei=nOaQVMDjNcGwogTy9YK4DA&usg=AFQjCNEAm-45Muq_nX5INW96szY5GEJGUg&sig2=jbFxMTxvkK2gQnbgTEs63Q&bvm=bv.82001339,d.cGU'), ('browser_language', 'fr,fr-fr;q=0.8,en-us;q=0.5,en;q=0.3'), ('course_id', 'v0l76HmGEeSi3yIACzSGcw'), ('country_cd', 'PF'), ('region_cd', 'V'), ('timezone', 'Pacific/Tahiti'), ('os', 'Mac OS X'), ('browser', 'Firefox'), ('key', 'pageview'), ('value', '{}')]), OrderedDict([('umich_user_id', '25424b1007637699cf0c672edc7a64c2b65268fa'), ('hashed_session_cookie_id', '1f0971d7bd2f12a3c3a85ba8870b0e9d8d2b4515'), ('server_timestamp', 'Thu Jan 01 03:00:26 EST 2015'), ('hashed_ip', 'e3979d142d5e89fa41 ...

# %% [markdown]
# Read the **first 10 lines** from ```mooc_data```. We will output the ```user id```, ```country code``` and ```full name of the country```.
# <font color="red">You will modify the next block of code to print.</font>

# %%
for row in mooc_data: #This will print all the rows. Change it so that it prints only the first 10
    #user_id = 
    #country_code =
    #full_name = country_names[row['country_cd']]
    print(row['umich_user_id'], row['country_cd'], country_names[row['country_cd']]) #Write down the code within the print statement so that it prints user id, country code, and country name
# Out:
# 0ea5cc6ff0ca76782e6c0a81f070cae9cf0971d9 PF French Polynesia
# 0ea5cc6ff0ca76782e6c0a81f070cae9cf0971d9 PF French Polynesia
# 5450de1c9e1874d613a9649a39352a10313a3b8f IT Italy
# 0ea5cc6ff0ca76782e6c0a81f070cae9cf0971d9 PF French Polynesia
# 25424b1007637699cf0c672edc7a64c2b65268fa US United States of America
# a95f04999ccf8fcd0f26fb0851745073a147e009 CZ Czech Republic
# 4ea0a18ab02a30290dda02bdb2da8a7a6a469245 US United States of America
# 25424b1007637699cf0c672edc7a64c2b65268fa US United States of America
# 44185055eece5d1bc7986d743d240a7633d968ff US United States of America
# 005aa91c779e6fe84b49398793dbda670dd6c352 NO Norway
# 005aa91c779e6fe84b49398793dbda670dd6c352 NO Norway
# 005aa91c779e6fe84b49398793dbda670dd6c352 NO Norway
# bb116a9af763fa2f53139c1dfa851c760a667169 DE Germany
# e996e19bc246066a26ed666c53bab9b78c0df08a EG Egypt
# 95cffc5948af183853735930299a0bc48c1cdc6c US United States of America
# 0ea5cc6ff0ca76782e6c0a81f070cae9cf0971d9 PF French Polynesia
# 17c1eed00cc46d9dfe62d95570d1b8e8846d5239 BY Belarus
# 0ea5cc6ff0ca76782e6c0a81f070cae9cf0971d9 PF French Polynesia
# 90e1b71e4948330711a9bb9f2df6818532945829 US United States of America
# 81f41b99410e89adfd934416faf87e361da5815f US United States of America
# 005aa91c779e6fe84b49398793dbda670dd6c352 NO Norway
# fa5a26c846e2b93a84c3e04a00215d3dc71bb6a4 AU Australia
# a9cd5f536994465902b0984126da044efd240878 PS Palestinian Territory
# a95f04999ccf8fcd0f26fb0851745073a147e009 CZ Czech Republic
# a95f04999ccf8fcd0f26fb0851745073a147e009 CZ Czech Republic
# a9cd5f536994465902b0984126da044efd240878 PS Palestinian Territory
# f9a7816134e0397b5f380ab082cdef5b37d3a323 US United States of America
# 44185055eece5d1bc7986d743d240a7633d968ff US United States of America
# 7fe732fdcf374ef1ea747a19e1eb28478c6ad656 US United States of America
# d96e283f9c70149eb110d1c56ceece3e3d925939 PL Poland
# 17c1eed00cc46d9dfe62d95570d1b8e8846d5239 BY Belarus
# 95cffc5948af183853735930299a0bc48c1cdc6c US United States of America
# ac0f295a5dfc41c87aa8f4865d35b0d00124fc19 GD Grenada
# c7e0b7e873392815abee61a53c231a1d5866a659 US United States of America
# bb116a9af763fa2f53139c1dfa851c760a667169 DE Germany
# bb116a9af763fa2f53139c1dfa851c760a667169 DE Germany
# 665ae36273cd614008b2ef7a203867c901bf01d2 CA Canada
# 1066a697903937dcb2bba46698b65c9067602b13 US United States of America
# c7e0b7e873392815abee61a53c231a1d5866a659 US United States of America
# ba41844ae5dba3fe42d7cc13c124d68062656cd2 US United States of America
# c7e0b7e873392815abee61a53c231a1d5866a659 US United States of America
# c43cc28e3cc1bcba91108a8d7363221e390da9cd BR Brazil
# c7e0b7e873392815abee61a53c231a1d5866a659 US United States of America
# 10980ee1943f363a092467cd9c66bea3304d523a CA Canada
# 6834ae47d226b2053f130fb9e52eab3c63212ca1 US United States of America
# 95cffc5948af183853735930299a0bc48c1cdc6c US United States of America
# 17c1eed00cc46d9dfe62d95570d1b8e8846d5239 BY Belarus
# 17c1eed00cc46d9dfe62d95570d1b8e8846d5239 BY Belarus
# ef31598a0a50ca98c411d19de710dc9d1f19d413 AU Australia
# b8ee892ce61b98c391c7f49dac24a32569548d15 US United States of America
# 1066a697903937dcb2bba46698b65c9067602b13 US United States of America
# bb116a9af763fa2f53139c1dfa851c760a667169 DE Germany
# c7e0b7e873392815abee61a53c231a1d5866a659 US United States of America
# ef31598a0a50ca98c411d19de710dc9d1f19d413 AU Australia
# c7e0b7e873392815abee61a53c231a1d5866a659 US United States of America
# 386a04196edf58eb3c6cd05e391b4b709ae9f42f CA Canada
# 44185055eece5d1bc7986d743d240a7633d968ff US United States of America
# 86dfa2d0e72d7818baf945a60070b79980fbb691 CA Canada
# bec8d341e667a015f933c171705ab73c3affdf03 US United States of America
# 826865822b68f6a6662f6dbbadad268801c140a3 AU Australia
# 1e791177b039f48de777a632003765c1ee10f349 US United States of America
# 7c08d6e31857a6cf120b5a22b5c659ead920e4dc US United States of America
# e4f952f0d86e23b93f89af96eb7b92ab5354b281 CA Canada
# e4f952f0d86e23b93f89af96eb7b92ab5354b281 CA Canada
# 70d530b2e677aa82a680b36ba534dbabc884e010 US United States of America
# 70d530b2e677aa82a680b36ba534dbabc884e010 US United States of America
# 1066a697903937dcb2bba46698b65c9067602b13 US United States of America
# 95b5bdb0c8007d9deb2adfdbc585300ca4346b9f US United States of America
# bb116a9af763fa2f53139c1dfa851c760a667169 DE Germany
# f9fe5547b353ab80baf63dbfd586d691bf8d3826 CN China
# 2ec5a8127aee5cb07eaa35ca3abc03d3c4179171 JM Jamaica
# 2ec5a8127aee5cb07eaa35ca3abc03d3c4179171 JM Jamaica
# e271b54251df988396ca1e32076867dd4ba78ff0 JP Japan
# 782769c43c43978564e030eedc6be9cd2ed6e304 AU Australia
# 32b73c34b1f858c72bfdb95114891bcc90f6856d US United States of America
# e4f952f0d86e23b93f89af96eb7b92ab5354b281 CA Canada
# 92a9df503fa2657333a42331ebd41fdb72b81ab6 LB Lebanon
# e4f952f0d86e23b93f89af96eb7b92ab5354b281 CA Canada
# 70d530b2e677aa82a680b36ba534dbabc884e010 US United States of America
# 1066a697903937dcb2bba46698b65c9067602b13 US United States of America
# 17c1eed00cc46d9dfe62d95570d1b8e8846d5239 BY Belarus
# bb116a9af763fa2f53139c1dfa851c760a667169 DE Germany
# 5ea1e0b32644f577a0f9f08f43d793a7f8c864ef US United States of America
# 5ea1e0b32644f577a0f9f08f43d793a7f8c864ef US United States of America
# 02b921627914e08b888160fafef88ab27dc9338c US United States of America
# fc4d9f2f92b758747eb2009b966ba95a51d67b30 IQ Iraq
# 6dc77e5d88674d7358f7a6f4fb40323a150d5b19 US United States of America
# 5450de1c9e1874d613a9649a39352a10313a3b8f IT Italy
# 6bcf7e85ae9729ca950c0397c8e3e940d58c2cdf JP Japan
# 7fe732fdcf374ef1ea747a19e1eb28478c6ad656 US United States of America
# c652fdea90bf6770420eb55236382b5353b347e6 US United States of America
# 386a04196edf58eb3c6cd05e391b4b709ae9f42f CA Canada
# 386a04196edf58eb3c6cd05e391b4b709ae9f42f CA Canada
# 4ea0a18ab02a30290dda02bdb2da8a7a6a469245 US United States of America
# bb116a9af763fa2f53139c1dfa851c760a667169 DE Germany
# ac0f295a5dfc41c87aa8f4865d35b0d00124fc19 GD Grenada
# 152b5f9c93e7b076b88f235b8581b9945f77c2e8 US United States of America
# 152b5f9c93e7b076b88f235b8581b9945f77c2e8 US United States of America
# 3e09689513e561c8381174b3d25a4ae779211159 US United States of America
# bb116a9af763fa2f53139c1dfa851c760a667169 DE Germany

# %% [markdown]
# ### Manipulating the data
#
# Next, we want to store the data into a data structure which will make it easier for us to perform operations on it later. We will create a dictionary of lists.
# <font color='red'>Using ```defaultdict```, store for each country a list of log entries. For now, we will only store the ```umich_user_id``` for the log.</font>

# %%
country_user_data = defaultdict(list) #you can put ** int(defaultdict(list)) **

print(country_user_data)
for i in mooc_data:
    country_user_data[i['country_cd']].append(i['umich_user_id']) #(list of all user ids for that country ) 
        # pass # modify this line to create a dictionary of lists. Each list must store the user ids of the users from that country.
for k, v in country_user_data.items():
    print(k,v) 

# country_user_data = defaultdict(int)

# print(country_user_data)
# for i in mooc_data:
#     country_user_data[i['country_cd']]+=1
#     print (i)
# Out:
# defaultdict(<class 'list'>, {})
# PF ['0ea5cc6ff0ca76782e6c0a81f070cae9cf0971d9', '0ea5cc6ff0ca76782e6c0a81f070cae9cf0971d9', '0ea5cc6ff0ca76782e6c0a81f070cae9cf0971d9', '0ea5cc6ff0ca76782e6c0a81f070cae9cf0971d9', '0ea5cc6ff0ca76782e6c0a81f070cae9cf0971d9']
# IT ['5450de1c9e1874d613a9649a39352a10313a3b8f', '5450de1c9e1874d613a9649a39352a10313a3b8f']
# US ['25424b1007637699cf0c672edc7a64c2b65268fa', '4ea0a18ab02a30290dda02bdb2da8a7a6a469245', '25424b1007637699cf0c672edc7a64c2b65268fa', '44185055eece5d1bc7986d743d240a7633d968ff', '95cffc5948af183853735930299a0bc48c1cdc6c', '90e1b71e4948330711a9bb9f2df6818532945829', '81f41b99410e89adfd934416faf87e361da5815f', 'f9a7816134e0397b5f380ab082cdef5b37d3a323', '44185055eece5d1bc7986d743d240a7633d968ff', '7fe732fdcf374ef1ea747a19e1eb28478c6ad656', '95cffc5948af183853735930299a0bc48c1cdc6c', 'c7e0b7e873392815abee61a53c231a1d5866a659', '1066a697903937dcb2bba46698b65c9067602b13', 'c7e0b7e873392815abee61a53c231a1d5866a659', 'ba41844ae5dba3fe42d7cc13c124d68062656cd2', 'c7e0b7e873392815abee61a53c231a1d5866a659', 'c7e0b7e873392815abee61a53c231a1d5866a659', '6834ae47d226b2053f130fb9e52eab3c63212ca1', '95cffc5948af183853735930299a0bc48c1cdc6c', 'b8ee892ce61b98c391c7f49dac24a32569548d15', '1066a697903937dcb2bba46698b65c9067602b13', 'c7e0b7e873392815abee61a53c231a1d5866a659', 'c7e0b7e873392815abee61a53c231a1d5866a659', '44185055eece5d1bc7986d743d240a7633d968ff', 'bec8d341e667a015f933c171705ab73c3affdf03', '1e791177b039f48de777a632003765c1ee10f349', '7c08d6e31857a6cf120b5a22b5c659ead920e4dc', '70d530b2e677aa82a680b36ba534dbabc884e010', '70d530b2e677aa82a680b36ba534dbabc884e010', '1066a697903937dcb2bba46698b65c9067602b13', '95b5bdb0c8007d9deb2adfdbc585300ca4346b9f', '32b73c34b1f858c72bfdb95114891bcc90f6856d', '70d530b2e677aa82a680b36ba534dbabc884e010', '1066a697903937dcb2bba46698b65c9067602b13', '5ea1e0b32644f577a0f9f08f43d793a7f8c864ef', '5ea1e0b32644f577a0f9f08f43d793a7f8c864ef', '02b921627914e08b888160fafef88ab27dc9338c', '6dc77e5d88674d7358f7a6f4fb40323a150d5b19', '7fe732fdcf374ef1ea747a19e1eb28478c6ad656', 'c652fdea90bf6770420eb55236382b5353b347e6', '4ea0a18ab02a30290dda02bdb2da8a7a6a469245', '152b5f9c93e7b076b88f235b8581b9945f77c2e8', '152b5f9c93e7b076b88f235b8581b9945f77c2e8', '3e09689513e561c8381174b3d25a4ae779211159']
# CZ ['a95f04999ccf8fcd0f26fb0851745073a147e009', 'a95f04999ccf8fcd0f26fb0851745073a147e009', 'a95f04999ccf8fcd0f26fb0851745073a147e009']
# NO ['005aa91c779e6fe84b49398793dbda670dd6c352', '005aa91c779e6fe84b49398793dbda670dd6c352', '005aa91c779e6fe84b49398793dbda670dd6c352', '005aa91c779e6fe84b49398793dbda670dd6c352']
# DE ['bb116a9af763fa2f53139c1dfa851c760a667169', 'bb116a9af763fa2f53139c1dfa851c760a667169', 'bb116a9af763fa2f53139c1dfa851c760a667169', 'bb116a9af763fa2f53139c1dfa851c760a667169', 'bb116a9af763fa2f53139c1dfa851c760a667169', 'bb116a9af763fa2f53139c1dfa851c760a667169', 'bb116a9af763fa2f53139c1dfa851c760a667169', 'bb116a9af763fa2f53139c1dfa851c760a667169']
# EG ['e996e19bc246066a26ed666c53bab9b78c0df08a']
# BY ['17c1eed00cc46d9dfe62d95570d1b8e8846d5239', '17c1eed00cc46d9dfe62d95570d1b8e8846d5239', '17c1eed00cc46d9dfe62d95570d1b8e8846d5239', '17c1eed00cc46d9dfe62d95570d1b8e8846d5239', '17c1eed00cc46d9dfe62d95570d1b8e8846d5239']
# AU ['fa5a26c846e2b93a84c3e04a00215d3dc71bb6a4', 'ef31598a0a50ca98c411d19de710dc9d1f19d413', 'ef31598a0a50ca98c411d19de710dc9d1f19d413', '826865822b68f6a6662f6dbbadad268801c140a3', '782769c43c43978564e030eedc6be9cd2ed6e304']
# PS ['a9cd5f536994465902b0984126da044efd240878', 'a9cd5f536994465902b0984126da044efd240878']
# PL ['d96e283f9c70149eb110d1c56ceece3e3d925939']
# GD ['ac0f295a5dfc41c87aa8f4865d35b0d00124fc19', 'ac0f295a5dfc41c87aa8f4865d35b0d00124fc19']
# CA ['665ae36273cd614008b2ef7a203867c901bf01d2', '10980ee1943f363a092467cd9c66bea3304d523a', '386a04196edf58eb3c6cd05e391b4b709ae9f42f', '86dfa2d0e72d7818baf945a60070b79980fbb691', 'e4f952f0d86e23b93f89af96eb7b92ab5354b281', 'e4f952f0d86e23b93f89af96eb7b92ab5354b281', 'e4f952f0d86e23b93f89af96eb7b92ab5354b281', 'e4f952f0d86e23b93f89af96eb7b92ab5354b281', '386a04196edf58eb3c6cd05e391b4b709ae9f42f', '386a04196edf58eb3c6cd05e391b4b709ae9f42f']
# BR ['c43cc28e3cc1bcba91108a8d7363221e390da9cd']
# CN ['f9fe5547b353ab80baf63dbfd586d691bf8d3826']
# JM ['2ec5a8127aee5cb07eaa35ca3abc03d3c4179171', '2ec5a8127aee5cb07eaa35ca3abc03d3c4179171']
# JP ['e271b54251df988396ca1e32076867dd4ba78ff0', '6bcf7e85ae9729ca950c0397c8e3e940d58c2cdf']
# LB ['92a9df503fa2657333a42331ebd41fdb72b81ab6']
# IQ ['fc4d9f2f92b758747eb2009b966ba95a51d67b30']

# %% [markdown]
# ### Filtering the data
#
# We want to find out the number of different users overall, and from the US. For that we will first need to filter ```country_user_data``` to retrieve data from the US, and store it in ```us_user_data```. Since we are using a dictionary, this is relatively straightforward.

# %%
#us_user_data = country_user_data['US']

# %% [markdown]
# ### Operations on the data
#
# To get the number of unique users in the data, we can do it in two different ways - **dictionaries** and **sets**.
#
# Dictionaries are commonly used. The advantage of dictionaries is that each key will be that of an unique user, while the corresponding value to that key will allow you to store the number of logs for that user.

# %% [markdown]
# <font color="red">In the following code block you will use **dictionaries** to count unique users and the number of logs for each. Write down the code using ```defaultdict```.</font>

# %%
### Using Dictionaries
unique_user_data_overall = defaultdict(int)
unique_user_data_us = defaultdict(int)
for i in mooc_data:
    unique_user_data_overall[i['umich_user_id']]+=1
    if i['country_cd']=='US':
        unique_user_data_us [i['umich_user_id']]+=1
print (unique_user_data_overall)
    

print("Total no. of unique users: ", len(unique_user_data_overall))
print("No. of unique users from the US: ", len(unique_user_data_us))
# Out:
# defaultdict(<class 'int'>, {'0ea5cc6ff0ca76782e6c0a81f070cae9cf0971d9': 5, '5450de1c9e1874d613a9649a39352a10313a3b8f': 2, '25424b1007637699cf0c672edc7a64c2b65268fa': 2, 'a95f04999ccf8fcd0f26fb0851745073a147e009': 3, '4ea0a18ab02a30290dda02bdb2da8a7a6a469245': 2, '44185055eece5d1bc7986d743d240a7633d968ff': 3, '005aa91c779e6fe84b49398793dbda670dd6c352': 4, 'bb116a9af763fa2f53139c1dfa851c760a667169': 8, 'e996e19bc246066a26ed666c53bab9b78c0df08a': 1, '95cffc5948af183853735930299a0bc48c1cdc6c': 3, '17c1eed00cc46d9dfe62d95570d1b8e8846d5239': 5, '90e1b71e4948330711a9bb9f2df6818532945829': 1, '81f41b99410e89adfd934416faf87e361da5815f': 1, 'fa5a26c846e2b93a84c3e04a00215d3dc71bb6a4': 1, 'a9cd5f536994465902b0984126da044efd240878': 2, 'f9a7816134e0397b5f380ab082cdef5b37d3a323': 1, '7fe732fdcf374ef1ea747a19e1eb28478c6ad656': 2, 'd96e283f9c70149eb110d1c56ceece3e3d925939': 1, 'ac0f295a5dfc41c87aa8f4865d35b0d00124fc19': 2, 'c7e0b7e873392815abee61a53c231a1d5866a659': 6, '665ae36273cd614008b2ef7a203867c901bf01d2': 1, '1066a697903937dcb2bba46698b65c9067602b13': 4, 'ba41844ae5dba3fe42d7cc13c124d68062656cd2': 1, 'c43cc28e3cc1bcba91108a8d7363221e390da9cd': 1, '10980ee1943f363a092467cd9c66bea3304d523a': 1, '6834ae47d226b2053f130fb9e52eab3c63212ca1': 1, 'ef31598a0a50ca98c411d19de710dc9d1f19d413': 2, 'b8ee892ce61b98c391c7f49dac24a32569548d15': 1, '386a04196edf58eb3c6cd05e391b4b709ae9f42f': 3, '86dfa2d0e72d7818baf945a60070b79980fbb691': 1, 'bec8d341e667a015f933c171705ab73c3affdf03': 1, '826865822b68f6a6662f6dbbadad268801c140a3': 1, '1e791177b039f48de777a632003765c1ee10f349': 1, '7c08d6e31857a6cf120b5a22b5c659ead920e4dc': 1, 'e4f952f0d86e23b93f89af96eb7b92ab5354b281': 4, '70d530b2e677aa82a680b36ba534dbabc884e010': 3, '95b5bdb0c8007d9deb2adfdbc585300ca4346b9f': 1, 'f9fe5547b353ab80baf63dbfd586d691bf8d3826': 1, '2ec5a8127aee5cb07eaa35ca3abc03d3c4179171': 2, 'e271b54251df988396ca1e32076867dd4ba78ff0': 1, '782769c43c43978564e030eedc6be9cd2ed6e304': 1, '32b73c34b1f858c72bfdb95114891bcc90f6856d': 1, '92a9df503fa2657333a42331ebd41fdb72b81ab6': 1, '5ea1e0b32644f577a0f9f08f43d793a7f8c864ef': 2, '02b921627914e08b888160fafef88ab27dc9338c': 1, 'fc4d9f2f92b758747eb2009b966ba95a51d67b30': 1, '6dc77e5d88674d7358f7a6f4fb40323a150d5b19': 1, '6bcf7e85ae9729ca950c0397c8e3e940d58c2cdf': 1, 'c652fdea90bf6770420eb55236382b5353b347e6': 1, '152b5f9c93e7b076b88f235b8581b9945f77c2e8': 2, '3e09689513e561c8381174b3d25a4ae779211159': 1})
# Total no. of unique users:  51
# No. of unique users from the US:  25

# %% [markdown]
# Another way of counting unique users in using sets. In the following block you will create two sets to store the ids of users globally, and from the US. A set will only store unique ids, unlike a list.
# <font color='red'>In the following chunk, we get a set of all the unique users globally. Write down the code to store in a separate set ```unique_us_users``` the set of users from the US.

# %%
### Using Sets
unique_users = set()
unique_us_users = set()
for i in mooc_data:
    unique_users.add(i['umich_user_id'])
    if i['country_cd']=='US':
        unique_us_users.add(i['umich_user_id'])
    #pass # Write down the code to create a set of users from the US.

print("Total no. of unique users: ", len(unique_users))
print("No. of unique users from the US: ", len(unique_us_users))
# Out:
# Total no. of unique users:  51
# No. of unique users from the US:  25

# %% [markdown]
# #### Average number of logs globally, and for users from the US.
# Here we will write the code to get the average number of logs for each user. We can use the dictionaries that we created previously, ```unique_user_data_overall``` and ```unique_user_data_us``` to compute this.

# %%
global_mean_logs_per_user = sum(unique_user_data_overall.values()) / len(unique_users)#None #Calculate the sum over the values of the dictionary. Divide by the length of the dictionary
us_mean_logs_per_user = sum(unique_user_data_us.values()) / len(unique_us_users)

print("Total no. of unique users: ", global_mean_logs_per_user)
print("No. of unique users from the US: ", us_mean_logs_per_user)
# Out:
# Total no. of unique users:  1.9607843137254901
# No. of unique users from the US:  1.76

# %% [markdown]
# ### Sorting
# Getting the ```user_id``` of the top 10 users who visited the most pages, globally and from the US. We will implement the ```sorted``` and pass a ```lambda``` function through the ```key``` parameter.
#
# **<font color="red">Write down the code for the lambda function.</font>**

# %%
sorted_us_data = sorted(unique_user_data_us.items(),key= lambda x:x[1], reverse = True) # Fill in within the parenthesis to sort the dictionary unique_user_data_us by the number of logs in the descending order

for i in range(5):
    print(sorted_us_data[i]) # Do not change this. This will output the top 5 users.
# Out:
# ('c7e0b7e873392815abee61a53c231a1d5866a659', 6)
# ('1066a697903937dcb2bba46698b65c9067602b13', 4)
# ('44185055eece5d1bc7986d743d240a7633d968ff', 3)
# ('95cffc5948af183853735930299a0bc48c1cdc6c', 3)
# ('70d530b2e677aa82a680b36ba534dbabc884e010', 3)
